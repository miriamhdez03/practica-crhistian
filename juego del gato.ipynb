# %%
a11=0
a12=0
a13=0
b11=0
b12=0
b13=0
c11=0
c12=0
c13=0
bandera=0

jugador1=input('Ingresa 1 la casilla: ')
if(jugador1=="a11"):
  a11=1
elif(jugador1=="a12"):
  a12=1
elif(jugador1=="a13"):
  a13=1
elif(jugador1=="b11"):
  b11=1
elif(jugador1=="b12"):
  b12=1
elif(jugador1=="b13"):
  b13=1
elif(jugador1=="c11"):
  c11=1
elif(jugador1=="c12"):
  c12=1
elif(jugador1=="c13"):
  c13=1
  
jugador2=input('Ingresa 2 la casilla: ')
if(jugador2=="a11"):
  a11=2
elif(jugador2=="a12"):
  a12=2
elif(jugador2=="a13"):
  a13=2
elif(jugador2=="b11"):
  b11=2
elif(jugador2=="b12"):
  b12=2
elif(jugador2=="b13"):
  b13=2
elif(jugador2=="c11"):
  c11=2
elif(jugador2=="c12"):
  c12=2
elif(jugador2=="c13"):
  c13=2

jugador1=input('Ingresa 1 la casilla: ')
if(jugador1=="a11"):
  a11=1
elif(jugador1=="a12"):
  a12=1
elif(jugador1=="a13"):
  a13=1
elif(jugador1=="b11"):
  b11=1
elif(jugador1=="b12"):
  b12=1
elif(jugador1=="b13"):
  b13=1
elif(jugador1=="c11"):
  c11=1
elif(jugador1=="c12"):
  c12=1
elif(jugador1=="c13"):
  c13=1

jugador2=input('Ingresa 2 la casilla: ')
if(jugador2=="a11"):
  a11=2
elif(jugador2=="a12"):
  a12=2
elif(jugador2=="a13"):
  a13=2
elif(jugador2=="b11"):
  b11=2
elif(jugador2=="b12"):
  b12=2
elif(jugador2=="b13"):
  b13=2
elif(jugador2=="c11"):
  c11=2
elif(jugador2=="c12"):
  c12=2
elif(jugador2=="c13"):
  c13=2


jugador1=input('Ingresa 1 la casilla: ')
if(jugador1=="a11"):
  a11=1
elif(jugador1=="a12"):
  a12=1
elif(jugador1=="a13"):
  a13=1
elif(jugador1=="b11"):
  b11=1
elif(jugador1=="b12"):
  b12=1
elif(jugador1=="b13"):
  b13=1
elif(jugador1=="c11"):
  c11=1
elif(jugador1=="c12"):
  c12=1
elif(jugador1=="c13"):
  c13=1

if((a11==1) and (a12==1)and(a13==1)):
  print("Gana jugador 1")
  bandera=1
elif((b11==1) and (b12==1)and(b13==1)):
  print("Gana jugador 1")
  bandera=1
elif((c11==1) and (c12==1)and(c13==1)):
  print("Gana jugador 1")
  bandera=1
elif((a11==1) and (b11==1)and(c11==1)):
  print("Gana jugador 1")
  bandera=1
elif((a12==1) and (b12==1)and(c12==1)):
  print("Gana jugador 1")
  bandera=1
elif((a13==1) and (b13==1)and(c13==1)):
  print("Gana jugador 1")
  bandera=1
elif((a11==1) and (b12==1)and(c13==1)):
  print("Gana jugador 1")
  bandera=1
elif((c11==1) and (b12==1)and(a13==1)):
  print("Gana jugador 1")
  bandera=1

if(bandera==0):
  jugador2=input('Ingresa 2 la casilla: ')
  if(jugador2=="a11"):
    a11=2
  elif(jugador2=="a12"):
    a12=2
  elif(jugador2=="a13"):
    a13=2
  elif(jugador2=="b11"):
    b11=2
  elif(jugador2=="b12"):
    b12=2
  elif(jugador2=="b13"):
    b13=2
  elif(jugador2=="c11"):
    c11=2
  elif(jugador2=="c12"):
    c12=2
  elif(jugador2=="c13"):
    c13=2

  if((c11==2) and (b12==2)and(a13==2)):
    print("Gana jugador 2")
    bandera=1
  elif((a13==2) and (b12==2)and(c11==2)):
    print("Gana jugador 2")
    bandera=1
  elif((c13==2) and (b13==2)and(a12==2)):
    print("Gana jugador 2")
    bandera=1
  elif((a13==2) and (a12==2)and(a11==2)):
    print("Gana jugador 2")
    bandera=1
  elif((c11==2) and (b11==2)and(a11==2)):
    print("Gana jugador 2")
    bandera=1
  elif((b13==2) and (b12==2)and(b11==2)):
    print("Gana jugador 2")
    bandera=1
  elif((c12==2) and (b12==2)and(a12==2)):
    print("Gana jugador 2")
    bandera=1
  elif((c13==2) and (c12==2)and(c11==2)):
    print("Gana jugador 2")
    bandera=1

if(bandera==0):
  jugador1=input('Ingresa 1 la casilla: ')
  if(jugador1=="a11"):
    a11=1
  elif(jugador1=="a12"):
    a12=1
  elif(jugador1=="a13"):
    a13=1
  elif(jugador1=="b11"):
    b11=1
  elif(jugador1=="b12"):
    b12=1
  elif(jugador1=="b13"):
    b13=1
  elif(jugador1=="c11"):
    c11=1
  elif(jugador1=="c12"):
    c12=1
  elif(jugador1=="c13"):
    c13=1

  if((a11==1) and (a12==1)and(a13==1)):
    print("Gana jugador 1")
    bandera=1
  elif((b11==1) and (b12==1)and(b13==1)):
    print("Gana jugador 1")
    bandera=1
  elif((c11==1) and (c12==1)and(c13==1)):
    print("Gana jugador 1")
    bandera=1
  elif((a11==1) and (b11==1)and(b11==1)):
    print("Gana jugador 1")
    bandera=1
  elif((a12==1) and (b12==1)and(c12==1)):
    print("Gana jugador 1")
    bandera=1
  elif((a13==1) and (b13==1)and(c13==1)):
    print("Gana jugador 1")
    bandera=1
  elif((a11==1) and (b12==1)and(c13==1)):
    print("Gana jugador 1")
    bandera=1
  elif((c11==1) and (b12==1)and(a13==1)):
    print("Gana jugador 1")
    bandera=1

if(bandera==0):
  jugador2=input('Ingresa 2 la casilla: ')
  if(jugador2=="a11"):
    a11=2
  elif(jugador2=="a12"):
    a12=2
  elif(jugador2=="a13"):
    a13=2
  elif(jugador2=="b11"):
    b11=2
  elif(jugador2=="b12"):
    b12=2
  elif(jugador2=="b13"):
    b13=2
  elif(jugador2=="c11"):
    c11=2
  elif(jugador2=="c12"):
    c12=2
  elif(jugador2=="c13"):
    c13=2


  if((c11==2) and (b12==2)and(a13==2)):
    print("Gana jugador 2")
    bandera=1
  elif((a13==2) and (b12==2)and(c11==2)):
    print("Gana jugador 2")
    bandera=1
  elif((c13==2) and (b13==2)and(a12==2)):
    print("Gana jugador 2")
    bandera=1
  elif((a13==2) and (a12==2)and(a11==2)):
    print("Gana jugador 2")
    bandera=1
  elif((c11==2) and (b11==2)and(a11==2)):
    print("Gana jugador 2")
    bandera=1
  elif((b13==2) and (b12==2)and(b11==2)):
    print("Gana jugador 2")
    bandera=1
  elif((c12==2) and (b12==2)and(a12==2)):
    print("Gana jugador 2")
    bandera=1
  elif((c13==2) and (c12==2)and(c11==2)):
    print("Gana jugador 2")
    bandera=1

if(bandera==0):
  jugador1=input('Ingresa 1 la casilla: ')
  if(jugador1=="a11"):
    a11=1
  elif(jugador1=="a12"):
    a12=1
  elif(jugador1=="a13"):
    a13=1
  elif(jugador1=="b11"):
    b11=1
  elif(jugador1=="b12"):
    b12=1
  elif(jugador1=="b13"):
    b13=1
  elif(jugador1=="c11"):
    c11=1
  elif(jugador1=="c12"):
    c12=1
  elif(jugador1=="c13"):
    c13=1

  if((a11==1) and (a12==1)and(a13==1)):
    print("Gana jugador 1")
    bandera=1
  elif((b11==1) and (b12==1)and(b13==1)):
    print("Gana jugador 1")
    bandera=1
  elif((c11==1) and (c12==1)and(c13==1)):
    print("Gana jugador 1")
    bandera=1
  elif((a11==1) and (b11==1)and(b11==1)):
    print("Gana jugador 1")
    bandera=1
  elif((a12==1) and (b12==1)and(c12==1)):
    print("Gana jugador 1")
    bandera=1
  elif((a13==1) and (b13==1)and(c13==1)):
    print("Gana jugador 1")
    bandera=1
  elif((a11==1) and (b12==1)and(c13==1)):
    print("Gana jugador 1")
    bandera=1
  elif((c11==1) and (b12==1)and(a13==1)):
    print("Gana jugador 1")
    bandera=1
    
  else:
    print("EMPATE")
# Out:
# Ingresa 1 la casilla: a11
# Ingresa 2 la casilla: b11
# Ingresa 1 la casilla: a12
# Ingresa 2 la casilla: b12
# Ingresa 1 la casilla: a13
# Gana jugador 1
